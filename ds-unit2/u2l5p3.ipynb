# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import math
import warnings
from sklearn import linear_model
from sklearn.cross_decomposition import PLSRegression
# %matplotlib inline
sns.set_style('white')
sns.set_palette('mako')

warnings.filterwarnings(
    action='ignore',
    module='scipy',
    message="internal gelsd"
)

# %%
n = 1000
p = 10
X = np.random.normal(size=n * p).reshape((n,p))
y = X[:,0] + 2 * X[:, 1] + np.random.normal(size=n*1) + 5

# %%
f, ax = plt.subplots(figsize=(12,9))
corrmat = pd.DataFrame(np.insert(X,0,y,axis=1)).corr()
sns.set(style='whitegrid',palette='mako')
sns.heatmap(corrmat, vmax=.8, cmap='YlGnBu', square=True)
plt.show()

# %%
regr = linear_model.LinearRegression()
regr.fit(X,y)

y_pred = regr.predict(X)
print("R-squared regression:", regr.score(X,y))

pls1 = PLSRegression(n_components=3)

pls1.fit(X,y)

Y_PLS_pred = pls1.predict(X)

print('R-squared PLSR:', pls1.score(X,y))

plt.scatter(y_pred,Y_PLS_pred)
plt.xlabel('Predicted by original 10 features')
plt.ylabel('Predicted by 3 features')
plt.title('Comparing LR and PLSR predictions')
plt.show()
# Out:
# R-squared regression: 0.8326447352992375
# R-squared PLSR: 0.8326445837880518

# %%
n = 1000
p = 14
X = np.random.normal(size=n * p).reshape((n,p))
y = X[:,0] + 2 * X[:, 1] + np.random.normal(size=n*1) + 5

f, ax = plt.subplots(figsize=(12,9))
corrmat = pd.DataFrame(np.insert(X,0,y,axis=1)).corr()
sns.set(style='whitegrid',palette='mako')
sns.heatmap(corrmat, vmax=.8, cmap='YlGnBu', square=True)
plt.show()
regr = linear_model.LinearRegression()
regr.fit(X,y)

y_pred = regr.predict(X)
print("R-squared regression:", regr.score(X,y))
pls1 = PLSRegression(n_components=3)
pls1.fit(X,y)
Y_PLS_pred = pls1.predict(X)
print('R-squared PLSR:', pls1.score(X,y))


plt.scatter(y_pred,Y_PLS_pred)
plt.xlabel('Predicted by original 10 features')
plt.ylabel('Predicted by 3 features')
plt.title('Comparing LR and PLSR predictions')
plt.show()
# Out:
# R-squared regression: 0.8255018421641438
# R-squared PLSR: 0.8255008008157289

# %%
n = 1000
p = 7
X = np.random.normal(size=n * p).reshape((n,p))
y = X[:,0] + 2 * X[:, 1] + np.random.normal(size=n*1) + 5

f, ax = plt.subplots(figsize=(12,9))
corrmat = pd.DataFrame(np.insert(X,0,y,axis=1)).corr()
sns.set(style='whitegrid',palette='mako')
sns.heatmap(corrmat, vmax=.8, cmap='YlGnBu', square=True)
plt.show()
regr = linear_model.LinearRegression()
regr.fit(X,y)

y_pred = regr.predict(X)
print("R-squared regression:", regr.score(X,y))
pls1 = PLSRegression(n_components=3)
pls1.fit(X,y)
Y_PLS_pred = pls1.predict(X)
print('R-squared PLSR:', pls1.score(X,y))


plt.scatter(y_pred,Y_PLS_pred)
plt.xlabel('Predicted by original 10 features')
plt.ylabel('Predicted by 3 features')
plt.title('Comparing LR and PLSR predictions')
plt.show()
# Out:
# R-squared regression: 0.84458016339569
# R-squared PLSR: 0.844580134725679

# %%
n = 1000
p = 350
X = np.random.normal(size=n * p).reshape((n,p))
y = X[:,0] + 2 * X[:, 1] + np.random.normal(size=n*1) + 5

f, ax = plt.subplots(figsize=(12,9))
corrmat = pd.DataFrame(np.insert(X,0,y,axis=1)).corr()
sns.set(style='whitegrid',palette='mako')
sns.heatmap(corrmat, vmax=.8, cmap='YlGnBu', square=True)
plt.show()
regr = linear_model.LinearRegression()
regr.fit(X,y)

y_pred = regr.predict(X)
print("R-squared regression:", regr.score(X,y))
pls1 = PLSRegression(n_components=3)
pls1.fit(X,y)
Y_PLS_pred = pls1.predict(X)
print('R-squared PLSR:', pls1.score(X,y))


plt.scatter(y_pred,Y_PLS_pred)
plt.xlabel('Predicted by original 10 features')
plt.ylabel('Predicted by 3 features')
plt.title('Comparing LR and PLSR predictions')
plt.show()
# Out:
# R-squared regression: 0.8840316093559271
# R-squared PLSR: 0.8707372730935868

# %%
n = 10000
p = 50
X = np.random.normal(size=n * p).reshape((n,p))
y = X[:,25] + math.sin(5) * (X[:, 37]) + np.random.normal(size=n*1) + 5

f, ax = plt.subplots(figsize=(12,9))
corrmat = pd.DataFrame(np.insert(X,0,y,axis=1)).corr()
sns.set(style='whitegrid',palette='mako')
sns.heatmap(corrmat, vmax=.8, cmap='YlGnBu', square=True)
plt.show()
regr = linear_model.LinearRegression()
regr.fit(X,y)

y_pred = regr.predict(X)
print("R-squared regression:", regr.score(X,y))
pls1 = PLSRegression(n_components=3)
pls1.fit(X,y)
Y_PLS_pred = pls1.predict(X)
print('R-squared PLSR:', pls1.score(X,y))


plt.scatter(y_pred,Y_PLS_pred)
plt.xlabel('Predicted by original 10 features')
plt.ylabel('Predicted by 3 features')
plt.title('Comparing LR and PLSR predictions')
plt.show()
# Out:
# R-squared regression: 0.6528937707809179
# R-squared PLSR: 0.6528937175321303

# %%
n = 10000
p = 50
X = np.random.normal(size=n * p).reshape((n,p))
y = X[:,25]**2 + (5) * (X[:, 37]) + np.random.normal(size=n*1) -3

f, ax = plt.subplots(figsize=(12,9))
corrmat = pd.DataFrame(np.insert(X,0,y,axis=1)).corr()
sns.set(style='whitegrid',palette='mako')
sns.heatmap(corrmat, vmax=.8, cmap='YlGnBu', square=True)
plt.show()
regr = linear_model.LinearRegression()
regr.fit(X,y)

y_pred = regr.predict(X)
print("R-squared regression:", regr.score(X,y))
pls1 = PLSRegression(n_components=3)
pls1.fit(X,y)
Y_PLS_pred = pls1.predict(X)
print('R-squared PLSR:', pls1.score(X,y))


plt.scatter(y_pred,Y_PLS_pred)
plt.xlabel('Predicted by original 10 features')
plt.ylabel('Predicted by 3 features')
plt.title('Comparing LR and PLSR predictions')
plt.show()
# Out:
# R-squared regression: 0.892247782970519
# R-squared PLSR: 0.8922477112497036

# %%
def plsr (n,p):
    n = n
    p = p
    X = np.random.normal(size=n * p).reshape((n,p))
    y = X[:,2]/2 + (5) * (X[:, 5]) + np.random.normal(size=n*1) +2 + X[:,8]

    f, ax = plt.subplots(figsize=(12,9))
    corrmat = pd.DataFrame(np.insert(X,0,y,axis=1)).corr()
    sns.set(style='whitegrid',palette='mako')
    sns.heatmap(corrmat, vmax=.8, cmap='YlGnBu', square=True)
    plt.show()
    regr = linear_model.LinearRegression()
    regr.fit(X,y)

    y_pred = regr.predict(X)
    print("R-squared regression:", regr.score(X,y))
    pls1 = PLSRegression(n_components=3)
    pls1.fit(X,y)
    Y_PLS_pred = pls1.predict(X)
    print('R-squared PLSR:', pls1.score(X,y))


    plt.scatter(y_pred,Y_PLS_pred)
    plt.xlabel('Predicted by original 10 features')
    plt.ylabel('Predicted by 3 features')
    plt.title('Comparing LR and PLSR predictions')
    plt.show()

# %%
plsr(1000,11)
# Out:
# R-squared regression: 0.9650842503596833
# R-squared PLSR: 0.9650840435738471

# %%
plsr(100000,23)
# Out:
# R-squared regression: 0.9631241447076165
# R-squared PLSR: 0.9631241446933174
